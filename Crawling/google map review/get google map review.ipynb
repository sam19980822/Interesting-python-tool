# %% [markdown]
# ### 參考資料來源
# 資料操作:
# https://medium.com/jameslearningnote/%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92-%E7%AC%AC2-2%E8%AC%9B-%E5%A6%82%E4%BD%95%E7%8D%B2%E5%8F%96%E8%B3%87%E6%96%99-google-map-api-beb7c88dc4e3
#
# 獲取API金鑰
# https://developers.google.com/places/web-service/get-api-key?hl=zh-tw
#
# 激活金鑰
# https://console.cloud.google.com/apis/credentials?project=cama-cafe-review
#
# Google Maps API 官方文件
# https://developers.google.com/maps/gmp-get-started#enable-api-sdk

# %%
import googlemaps
from datetime import datetime
import time as time

gmaps = googlemaps.Client(key='AIzaSyDB2tDDVepLXjp9UYSpoDn-zz7ns3ggEUA')

# # Geocoding an address
geocode_result = gmaps.geocode('臺北市')

# # # Look up an address with reverse geocoding
# reverse_geocode_result = gmaps.reverse_geocode((25.03119, 121.546207))

# # Request directions via public transit
# now = datetime.now()
# directions_result = gmaps.directions("Daan metro station",
#                                      "National Taiwan University",
#                                      mode="transit",
#                                      departure_time=now)

# %%
cities= ["臺北市","新北市","桃園市","臺中市","臺南市","高雄市","基隆市","新竹市","嘉義市","新竹縣",
        "苗栗縣","彰化縣","南投縣","雲林縣","嘉義縣","屏東縣","宜蘭縣","花蓮縣","臺東縣","澎湖縣"]

# %%
geocode_result = gmaps.geocode("臺北市")
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Taipei',
#     'short_name': 'Taipei',
#     'types': ['colloquial_area', 'locality', 'political']},
#    {'long_name': 'Taiwan',
#     'short_name': 'TW',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Taipei, Taiwan',
#   'geometry': {'bounds': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}},
#    'location': {'lat': 25.0329694, 'lng': 121.5654177},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 25.2443731, 'lng': 121.7300824},
#     'southwest': {'lat': 24.7900797, 'lng': 121.2826735}}},
#   'place_id': 'ChIJmQrivHKsQjQR4MIK3c41aj8',
#   'types': ['colloquial_area', 'locality', 'political']}]

# %%
ids = []
for city in cities:
    results = []
    # Geocoding an address
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    query_result = gmaps.places_nearby(keyword="Cama",location=loc, radius=10000)
    results.extend(query_result['results'])
    while query_result.get('next_page_token'):
        time.sleep(2)
        query_result = gmaps.places_nearby(page_token=query_result['next_page_token'])
        results.extend(query_result['results'])    
    print("找到以"+city+"為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): "+str(len(results)))
    for place in results:
        ids.append(place['place_id'])
# Out:
# 找到以臺北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 60
# 找到以新北市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 55
# 找到以桃園市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 9
# 找到以臺中市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 55
# 找到以臺南市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 8
# 找到以高雄市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 9
# 找到以基隆市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 1
# 找到以新竹市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 12
# 找到以嘉義市為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 13
# 找到以新竹縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 7
# 找到以苗栗縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 1
# 找到以彰化縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 13
# 找到以南投縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 12
# 找到以雲林縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 4
# 找到以嘉義縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 2
# 找到以屏東縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 0
# 找到以宜蘭縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 3
# 找到以花蓮縣為中心半徑10000公尺的寵物店家數量(google mapi api上限提供60間): 19
# ...

# %%
stores_info = []
# 去除重複id
ids = list(set(ids)) 
for id in ids:
    stores_info.append(gmaps.place(place_id=id, language='zh-TW')['result'])

# %%
import pandas as pd
output = pd.DataFrame.from_dict(stores_info)

# %%
output
# Out:
#                                     address_components  \
# 0    [{'long_name': '474', 'short_name': '474', 'ty...
# 1    [{'long_name': '37之1號', 'short_name': '37之1號',...
# 2    [{'long_name': '251號', 'short_name': '251號', '...
# 3    [{'long_name': '號1樓', 'short_name': '號1樓', 'ty...
# 4    [{'long_name': '22', 'short_name': '22', 'type...
# ..                                                 ...
# 235  [{'long_name': '157-1號', 'short_name': '157-1號...
# 236  [{'long_name': '5-16', 'short_name': '5-16', '...
# 237  [{'long_name': '460號', 'short_name': '460號', '...
# 238  [{'long_name': '90', 'short_name': '90', 'type...
# 239  [{'long_name': '668號', 'short_name': '668號', '...
#
#                                            adr_address  \
# 0    <span class="postal-code">330</span><span clas...
# 1    <span class="postal-code">545</span><span clas...
# 2    <span class="postal-code">302</span><span clas...
# 3    <span class="postal-code">40651</span><span cl...
# ...
